# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.datasets import make_regression

# %%
## use to make a dummy data
X,Y=make_regression(n_samples=100,n_features=2,n_informative=2,noise=10,random_state=1)

# %%
X.shape,Y.shape
# Out:
# ((100, 2), (100,))

# %%
plt.subplot(1,2,1)
plt.scatter(X[:,0],Y)
plt.subplot(1,2,2)
plt.scatter(X[:,1],Y)

# %%
# %matplotlib notebook 
# use for 3d plots

# %%
from mpl_toolkits import mplot3d
fig=plt.figure(figsize=(10,7))
ax=plt.axes(projection="3d")
ax.scatter3D(X[:,0],X[:,1],Y,color="green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.coef_  # gives theta1 and theta2
# Out:
# array([31.30912998, 83.67831905])

# %%
model.intercept_  # gives theta0
# Out:
# 0.7303861711066588

# %%
model.predict([X[5],X[6]])
# Out:
# array([ -53.09601567, -101.45231618])

# %%
Y[5],Y[6]
# Out:
# (-54.42082334693827, -93.05401413962667)

# %%
model.score(X,Y)
# Out:
# 0.9818249824413999

# %% [markdown]
# ## working with linear regression previous question

# %%
x_train=pd.read_csv("/Users/abhaydeep/Documents/DataScience/DataScience/31.Linear regression/Training Data/Linear_X_Train.csv")

# %%
y_train=pd.read_csv("/Users/abhaydeep/Documents/DataScience/DataScience/31.Linear regression/Training Data/Linear_Y_Train.csv")

# %%
x=x_train.values
y=y_train.values.reshape((-1))

# %%
x.shape,y.shape
# Out:
# ((3750, 1), (3750,))

# %%
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model2=LinearRegression()
model2.fit(x,y)
# Out:
# LinearRegression()

# %%
model2.coef_,model2.intercept_
# Out:
# (array([80.54363185]), 3.727988284452732)

# %%
# hypothesis
y_=model2.intercept_+model2.coef_*x

# %%
plt.scatter(x,y)
plt.plot(x,y_,color="red")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_test=pd.read_csv("/Users/abhaydeep/Documents/DataScience/DataScience/31.Linear regression/Test Cases/Linear_X_Test.csv")

# %%
model2.predict(x_test)
# Out:
# array([-147.52847525,  -66.26699842, -200.06209345, ...,   14.0382031 ,
#         -18.66616899,  -51.07594693])

# %% [markdown]
# ### working with multiple linear regression previous question boston

# %%
from sklearn.datasets import load_boston

# %%
data=load_boston()

# %%
x=data.data
y=data.target

# %%
# lets do some train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(x,y)

# %%
model3=LinearRegression()
model3.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model3.score(X_train,y_train)
# Out:
# 0.7587602857279101

# %%
y_=model3.predict(X_test)

# %%
y_.shape
# Out:
# (127,)

# %%
y_test.shape,y_.shape
# Out:
# ((127,), (127,))

# %%
model3.score(X_test,y_test)
# Out:
# 0.6683522151043131
